# %%
import pandas as pd

df = pd.read_csv('owid-covid-data.csv')

# %%
import pandas as pd

df = pd.read_csv('owid-covid-data.csv')
print(df.columns)
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
import pandas as pd

df = pd.read_csv('owid-covid-data.csv')
print(df.head())
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df = pd.read_csv('owid-covid-data.csv')
print(df.isnull().sum())
# Out:
# iso_code                                        0
# continent                                   16665
# location                                        0
# date                                            0
# total_cases                                 37997
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       337901
# excess_mortality_cumulative                337901
# excess_mortality                           337901
# excess_mortality_cumulative_per_million    337901
# Length: 67, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

countries_of_interest = ['China', 'Rwanda', 'Zimbabwe', 'Ghana']
filtered_df = df[df['location'].isin(countries_of_interest)]

# %%
countries_of_interest = ['China', 'Rwanda', 'Zimbabwe', 'Ghana']
filtered_df = df[df['location'].isin(countries_of_interest)]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['new_cases'] = df['new_cases'].fillna(0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
for country in countries_of_interest:
    country_data = filtered_df[filtered_df['location'] == country]
    plt.plot(country_data['date'], country_data['new_cases'], label=country)

plt.title('New Cases Over Time by location')
plt.xlabel('date')
plt.ylabel('new_cases')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 5))
for country in countries_of_interest:
    country_data = filtered_df[filtered_df['location'] == country]
    plt.plot(country_data['date'], country_data['total_deaths'], label=country)

plt.title('Total Deaths Over Time by Country')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
df = pd.read_csv('owid-covid-data.csv')

# %%
print(df.head())
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df['new_rate'] = df['total_deaths'] / df['total_cases']

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Plot cumulative vaccinations
plt.figure(figsize=(10, 5))
for country in countries_of_interest:
    country_data = filtered_df[filtered_df['location'] == country]
    plt.plot(country_data['date'], country_data['total_vaccinations'], label=country)

plt.title('Cumulative Vaccinations Over Time by Country')
plt.xlabel('Date')
plt.ylabel('Total Vaccinations')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df['vassinations_per_hundred'] = (df['total_vaccinations'] / df['people_vaccinated']) * 100

# %% [markdown]
# Death Rates Are Not Proportional to Case Numbers
#
# Countries with high case counts (like China) have the highest death rates and also the vaccination coverage is high due factors like healthcare quality, early intervention, and resources.

# %% [markdown]
# # COVID-19 Vaccination Analysis
#
# ## Introduction
#
# This notebook explores COVID-19 trends across selected countries, focusing on:
# - Total and new cases
# - Death rates
# - Vaccination coverage
#
# ## Key Obs
#
# <!-- Vaccination Trends -->
#
# Countries like China, Rwanda, Zimbabwe, and Ghana show varied vaccination rates over time.
#
# The cumulative total vaccinations indicate differing rates of vaccine accessibility and distribution.
#
# <!-- Case Progression Over Time -->
#
# The data reveals fluctuations in new cases across different regions.
#
# Countries with higher vaccination rates tend to show a gradual decline in new cases, supporting the effectiveness of immunization efforts.
#
# <!-- Death Rate Analysis -->
#
# The death_rate = total_deaths / total_cases metric highlights disparities in healthcare response.
#
# Higher death rates in certain regions point to healthcare system vulnerabilities or delayed interventions.ervatiChina- **Germany** showed a steep rise in v, the coverage could be influenced by factors like healthcare quality, early intervention, and resources a t outbreaks.
# - Death rates vary significantly, possibly due to healthcare capacity and vaccination rates.
#
# ## Conclusion
#
# Vaccination plays a critical role in reducing deaths despite rising cases. Continued monitoring is needed.
